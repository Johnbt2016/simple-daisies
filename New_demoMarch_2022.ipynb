# %%
pip install -U pydaisi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydaisi import Daisi

# %%
daisi = Daisi("Print Hello")
# Out:
# [09:49:46] INFO     Calling                                                    ]8;id=228001;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=932705;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#270\270]8;;\
#                     https://app.daisi.io/pebble-api/daisies/connect?name=Print
#                     Hello
#            INFO     Found existing Daisi: 2263a2fe-31b1-4af7-9ff8-575cab3c7f0a ]8;id=478611;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=609417;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#284\284]8;;\

# %%
response = daisi.hello(name="World")

# %%
response.value
# Out:
# 'Hello World'

# %%
color = Daisi("ImageColorization")
# Out:
# [09:49:56] INFO     Calling https://app.daisi.io/pebble-api/daisies/connect?na ]8;id=889807;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=317259;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#270\270]8;;\
#                     me=ImageColorization
#            INFO     Found existing Daisi: 3574fe5a-d4d5-4b43-9cc9-b99c6a93c39b ]8;id=484062;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=495279;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#284\284]8;;\

# %%
from PIL import Image
a = Image.open('/Users/laiglejm/Downloads/B2DBy.jpeg')
a

# %%
obj = color.run(a)

# %%
obj.value
# Out:
# array([[[0.34627965, 0.34465662, 0.39607048],
#         [0.3349889 , 0.33976766, 0.41734594],
#         [0.3195607 , 0.3403648 , 0.4453749 ],
#         ...,
#         [0.24705958, 0.23881835, 0.21860006],
#         [0.2501562 , 0.23785737, 0.21854195],
#         [0.24593005, 0.23371273, 0.21804318]],
#
#        [[0.34021455, 0.34331626, 0.42127603],
#         [0.32838288, 0.34416303, 0.4404792 ],
#         [0.30929404, 0.34162778, 0.45598173],
#         ...,
#         [0.24271026, 0.2406655 , 0.21277186],
#         [0.24917987, 0.23844287, 0.21547076],
#         [0.24862894, 0.2329151 , 0.21740156]],
#
#        [[0.33539888, 0.34662905, 0.44873804],
#         [0.32008597, 0.34405494, 0.4576667 ],
#         [0.30739257, 0.3455857 , 0.47031933],
#         ...,
#         [0.24027735, 0.24152216, 0.2112625 ],
#         [0.24507332, 0.23962364, 0.21644595],
#         [0.24803412, 0.23810199, 0.22307324]],
#
#        ...,
#
#        [[0.5509194 , 0.58141875, 0.40977392],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(obj.value)
plt.show()
# Out:
# <Figure size 432x288 with 1 Axes>

# %%
news = Daisi("GoogleNews")
# Out:
# [09:50:05] INFO     Calling https://app.daisi.io/pebble-api/daisies/connect?na ]8;id=608901;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=811556;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#270\270]8;;\
#                     me=GoogleNews
#            INFO     Found existing Daisi: 62afa319-4408-49c0-ab64-38563f9cea2a ]8;id=423193;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=18615;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#284\284]8;;\

# %%
 n = news.get_news(query = 'Apple', num = 20)

# %%
results = n.value['title'].tolist()

# %%
classification = Daisi("Zero Shot Text Classification")
# Out:
# [09:50:15] INFO     Calling                                                    ]8;id=181635;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=379495;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#270\270]8;;\
#                     https://app.daisi.io/pebble-api/daisies/connect?name=Zero
#                     Shot Text Classification
# [09:50:16] INFO     Found existing Daisi: 237587e0-7c47-4a4f-afad-80370c8e98a4 ]8;id=457576;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=533618;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#284\284]8;;\

# %%
sentiment = classification.compute(text=results[4], candidate_labels="positive, negative")

# %%
sentiment.value
# Out:
# {
#     'result': {
#         'sequence': "Step one in Apple's sports strategy – Six Colors",
#         'labels': ['positive', 'negative'],
#         'scores': [0.8605650663375854, 0.13943493366241455]
#     }
# }

# %%
p = Daisi("Simple Prophet")
# Out:
# [09:50:24] INFO     Calling https://app.daisi.io/pebble-api/daisies/connect?na ]8;id=827300;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=883594;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#270\270]8;;\
#                     me=Simple Prophet
#            INFO     Found existing Daisi: f2e42e79-c785-4170-8719-8a88d5b80205 ]8;id=409657;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py\pydaisi.py]8;;\:]8;id=681419;file:///Users/laiglejm/miniforge3_v2/envs/tensorflow/lib/python3.9/site-packages/pydaisi/pydaisi.py#284\284]8;;\

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/laiglejm/Documents/Belmont/Code/simple-daisies/prophet/example_wp_log_peyton_manning.csv')

# %%
data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#       <th>y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2007-12-10</td>
#       <td>9.590761</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2007-12-11</td>
#       <td>8.519590</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2007-12-12</td>
#       <td>8.183677</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2007-12-13</td>
#       <td>8.072467</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2007-12-14</td>
#       <td>7.893572</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
# ...

# %%
res = p.predict(df=data, period = 2000)
